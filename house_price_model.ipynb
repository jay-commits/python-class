# %%
#Import the necessary libraries
import pandas as pd # Loading dataset
import numpy as np #Perform numerical calculations
import matplotlib.pyplot as plt #Python visualizations
import seaborn as sns #Statistical visualizations
from scipy import stats #Statistical inferencing
from statsmodels.stats.outliers_influence import variance_inflation_factor #Checking for multicollinearity
from statsmodels.tools.tools import add_constant #Adding y-intercept to our model
from statsmodels.formula.api import ols #Linear Regression
import statsmodels.api as sm #ANOVA/ F-Statistic
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler #Preprocessing data before ML
from sklearn.model_selection import train_test_split, GridSearchCV #split our data, get the best model parameters
from sklearn.linear_model import LinearRegression, Ridge, Lasso #Linear Regression
from sklearn.tree import DecisionTreeRegressor #Tree model
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor #Ensembling model
from sklearn.metrics import mean_squared_error, root_mean_squared_error, r2_score #Model evaluators
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

# %%
# load datatest
house_prices=pd.read_csv(r"house_prices_dataset.csv")
house_prices.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          1         2803      1153       1           0     0
# 1         5          3          783      9762       1           0     2
# 2         3          3         3412      2842       2           0     3
# 3         2          3         2222      9020       2           1     2
# 4         4          1         4713      1584       2           0     3
#
#    condition  grade  year_built  year_renovated  zipcode        lat  \
# 0          3      9        2003               0    98001  47.660671
# 1          4      4        2019               0    98003  47.681937
# 2          4      9        1961            1962    98002  47.182798
# 3          4      4        2008            1962    98004  47.440995
# 4          4      5        1987               0    98005  47.701306
#
#          long       price
# 0 -121.785347   835016.23
# 1 -122.151515   326073.09
# 2 -121.792089  1025404.09
# 3 -121.871224   758764.79
# 4 -122.416623  1314784.23

# %%
house_prices["waterfront"].value_counts()
# Out:
# waterfront
# 0    893
# 1    107
# Name: count, dtype: int64

# %%
house_prices["view"].value_counts()
# Out:
# view
# 1    265
# 0    259
# 3    250
# 2    226
# Name: count, dtype: int64

# %%
house_prices["condition"].value_counts()
# Out:
# condition
# 5    216
# 2    207
# 4    199
# 1    190
# 3    188
# Name: count, dtype: int64

# %%
house_prices["grade"].value_counts()
# Out:
# grade
# 12    111
# 1      95
# 3      91
# 10     90
# 8      86
# 4      85
# 5      80
# 9      80
# 6      76
# 11     75
# 7      72
# 2      59
# Name: count, dtype: int64

# %%
# drop zipcode column
house_prices=house_prices.drop("zipcode",axis=1)

# %%
house_prices.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          1         2803      1153       1           0     0
# 1         5          3          783      9762       1           0     2
# 2         3          3         3412      2842       2           0     3
# 3         2          3         2222      9020       2           1     2
# 4         4          1         4713      1584       2           0     3
#
#    condition  grade  year_built  year_renovated        lat        long  \
# 0          3      9        2003               0  47.660671 -121.785347
# 1          4      4        2019               0  47.681937 -122.151515
# 2          4      9        1961            1962  47.182798 -121.792089
# 3          4      4        2008            1962  47.440995 -121.871224
# 4          4      5        1987               0  47.701306 -122.416623
#
#         price
# 0   835016.23
# 1   326073.09
# 2  1025404.09
# 3   758764.79
# 4  1314784.23

# %%
# more info from our data
house_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bedrooms        1000 non-null   int64
#  1   bathrooms       1000 non-null   int64
#  2   sqft_living     1000 non-null   int64
#  3   sqft_lot        1000 non-null   int64
#  4   floors          1000 non-null   int64
#  5   waterfront      1000 non-null   int64
#  6   view            1000 non-null   int64
#  7   condition       1000 non-null   int64
#  8   grade           1000 non-null   int64
#  9   year_built      1000 non-null   int64
#  10  year_renovated  1000 non-null   int64
#  11  lat             1000 non-null   float64
#  12  long            1000 non-null   float64
#  13  price           1000 non-null   float64
# dtypes: float64(3), int64(11)
# memory usage: 109.5 KB

# %% [markdown]
# Exploratory Data Analysis
# .price distribution

# %%
# Exploratory Data Analysis
house_prices.describe()
# Out:
#           bedrooms    bathrooms  sqft_living     sqft_lot       floors  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.988000     2.038000  2792.998000  5447.602000     1.501000
# std       1.412746     0.819285  1288.747969  2614.572404     0.500249
# min       1.000000     1.000000   600.000000  1001.000000     1.000000
# 25%       2.000000     1.000000  1652.750000  3103.500000     1.000000
# 50%       3.000000     2.000000  2787.500000  5464.500000     2.000000
# 75%       4.000000     3.000000  3921.500000  7754.500000     2.000000
# max       5.000000     3.000000  4996.000000  9992.000000     2.000000
#
#         waterfront         view    condition        grade   year_built  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.107000     1.467000     3.044000     6.651000  1985.746000
# std       0.309268     1.126135     1.424814     3.548773    20.809385
# min       0.000000     0.000000     1.000000     1.000000  1950.000000
# 25%       0.000000     0.000000     2.000000     4.000000  1968.000000
# 50%       0.000000     1.000000     3.000000     7.000000  1986.000000
# 75%       0.000000     2.250000     4.000000    10.000000  2004.000000
# max       1.000000     3.000000     5.000000    12.000000  2021.000000
#
#        year_renovated          lat         long         price
# count     1000.000000  1000.000000  1000.000000  1.000000e+03
# mean       431.076000    47.443683  -122.009919  8.358796e+05
# std        819.312098     0.198316     0.292534  3.271162e+05
# min          0.000000    47.100252  -122.497067  2.075845e+05
# 25%          0.000000    47.275159  -122.259953  5.527969e+05
# 50%          0.000000    47.450923  -122.024822  8.460296e+05
# 75%          0.000000    47.609755  -121.748543  1.131182e+06
# max       2021.000000    47.798749  -121.500636  1.476859e+06

# %% [markdown]
# bedrooms data not skewed,mean and median are same

# %%
# price distribution
sns.histplot(data=house_prices,x="price",color="purple",kde=True)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Floors and prices
# Does the number of floors influence the price?

# %%
sns.barplot(data=house_prices,x="floors",y="price",color="blue")
plt.title("floor vs Prices")
plt.xlabel("floors")
plt.ylabel("price")
plt.show()

# %%
sns.barplot(data=house_prices,x="waterfront",y="price",color="blue")
plt.title("waterfront vs Prices")
plt.xlabel("floors")
plt.ylabel("price")
plt.show()

# %%
sns.countplot(data=house_prices,x="waterfront",color="#0069b4")
plt.title("waterfronts")
plt.xlabel("waterfront")
plt.ylabel("Frequency")
plt.show()

# %%
sns.lineplot(data=house_prices,x="year_built",y="price")
plt.title("house prices over the years")
plt.xlabel("Year")
plt.ylabel("Prices")
plt.show()

# %% [markdown]
# Correlation Analysis
# Relatioship between the independent variables and dependent variable
# perfect correlation=1
# no correlation=0
# strong positive= btwn=0.5 and 1
# strong negative=-0.5 and-1
# weak positive=btwn 0.1 and 0.5
# weak negative=btwn -0.1

# %%
# correlation Analysis
correlations=house_prices.corr()
print(correlations)
# Out:
#                 bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# bedrooms        1.000000  -0.003930    -0.020278 -0.028367 -0.015563
# bathrooms      -0.003930   1.000000     0.030190  0.002061  0.043870
# sqft_living    -0.020278   0.030190     1.000000 -0.014612  0.008787
# sqft_lot       -0.028367   0.002061    -0.014612  1.000000  0.014753
# floors         -0.015563   0.043870     0.008787  0.014753  1.000000
# waterfront      0.044181   0.051097    -0.017256 -0.002951  0.041364
# view            0.009189   0.048013     0.055540 -0.100164  0.046257
# condition      -0.016148   0.049160     0.024721  0.021185 -0.007084
# grade           0.015536  -0.011960     0.004750  0.007995  0.029799
# year_built     -0.028739   0.012309     0.040945  0.013263 -0.010553
# year_renovated -0.049568  -0.018157    -0.024732  0.033545 -0.017841
# lat             0.036425  -0.012870    -0.038860 -0.019825 -0.021462
# long           -0.014820  -0.009914    -0.017699  0.135227  0.012312
# price           0.051959   0.060793     0.986325 -0.020945  0.015929
#
#                 waterfront      view  condition     grade  year_built  \
# bedrooms          0.044181  0.009189  -0.016148  0.015536   -0.028739
# bathrooms         0.051097  0.048013   0.049160 -0.011960    0.012309
# sqft_living      -0.017256  0.055540   0.024721  0.004750    0.040945
# sqft_lot         -0.002951 -0.100164   0.021185  0.007995    0.013263
# floors            0.041364  0.046257  -0.007084  0.029799   -0.010553
# waterfront        1.000000 -0.005659   0.000663 -0.001511   -0.008838
# view             -0.005659  1.000000   0.017126 -0.060870   -0.003135
# condition         0.000663  0.017126   1.000000 -0.043285   -0.004451
# grade            -0.001511 -0.060870  -0.043285  1.000000   -0.010961
# year_built       -0.008838 -0.003135  -0.004451 -0.010961    1.000000
# year_renovated   -0.001083 -0.050396  -0.013699 -0.037687    0.004312
# lat               0.016522  0.003718  -0.002600  0.039896    0.008784
# long              0.031468 -0.016395  -0.000478  0.005800   -0.025812
# price             0.080397  0.065690   0.064545  0.087347    0.036437
#
#                 year_renovated       lat      long     price
# bedrooms             -0.049568  0.036425 -0.014820  0.051959
# bathrooms            -0.018157 -0.012870 -0.009914  0.060793
# sqft_living          -0.024732 -0.038860 -0.017699  0.986325
# sqft_lot              0.033545 -0.019825  0.135227 -0.020945
# floors               -0.017841 -0.021462  0.012312  0.015929
# waterfront           -0.001083  0.016522  0.031468  0.080397
# view                 -0.050396  0.003718 -0.016395  0.065690
# condition            -0.013699 -0.002600 -0.000478  0.064545
# grade                -0.037687  0.039896  0.005800  0.087347
# year_built            0.004312  0.008784 -0.025812  0.036437
# year_renovated        1.000000  0.013257  0.040492 -0.032089
# lat                   0.013257  1.000000  0.011819 -0.032323
# long                  0.040492  0.011819  1.000000 -0.016663
# price                -0.032089 -0.032323 -0.016663  1.000000

# %%
# correlation heatmap
plt.figure(figsize=(12,12))
sns.heatmap(data=correlations,cmap="PiYG",annot=True)
# Out:
# <Axes: >

# %%
house_prices.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          1         2803      1153       1           0     0
# 1         5          3          783      9762       1           0     2
# 2         3          3         3412      2842       2           0     3
# 3         2          3         2222      9020       2           1     2
# 4         4          1         4713      1584       2           0     3
#
#    condition  grade  year_built  year_renovated        lat        long  \
# 0          3      9        2003               0  47.660671 -121.785347
# 1          4      4        2019               0  47.681937 -122.151515
# 2          4      9        1961            1962  47.182798 -121.792089
# 3          4      4        2008            1962  47.440995 -121.871224
# 4          4      5        1987               0  47.701306 -122.416623
#
#         price
# 0   835016.23
# 1   326073.09
# 2  1025404.09
# 3   758764.79
# 4  1314784.23

# %% [markdown]
# Variance Inflation Factor
# can be used to check for multicollinearity
# multicollinearity -correlation btwn indepent variables

# %%
# extract dependent and independt variables
y=house_prices["price"]
x=house_prices.drop("price",axis=1)

# %%
# vif
x = add_constant(x)

# compute VIF
vif_data=pd.DataFrame()
vif_data["Feature"]=x.columns
vif_data["VIF"]=[variance_inflation_factor(x.values,i)
                 for i in range(x.shape[1])]
print(vif_data)
# Out:
#            Feature            VIF
# 0            const  245124.428644
# 1         bedrooms       1.008525
# 2        bathrooms       1.010433
# 3      sqft_living       1.009111
# 4         sqft_lot       1.031680
# 5           floors       1.008315
# 6       waterfront       1.008007
# 7             view       1.024047
# 8        condition       1.006046
# 9            grade       1.010532
# 10      year_built       1.004037
# 11  year_renovated       1.010107
# 12             lat       1.006233
# 13            long       1.022586

# %% [markdown]
# ANOVA (f-statistic)
# Hypothesis testing
# checking for significance of the independent variables with relation to the dependent variable
# OLS to fit our model and get the f-statistic

# %%
formula="price~bedrooms+bathrooms+sqft_living+sqft_lot+floors+year_built+year_renovated+lat+long+C(waterfront)+C(view)+C(condition)+C(grade)" 
lm=ols(formula=formula,data=house_prices).fit()
table= sm.stats.anova_lm(lm,typ=2)
print(table)
# Out:
#                       sum_sq     df              F         PR(>F)
# C(waterfront)   9.162279e+11    1.0    2418.866823  7.457463e-266
# C(view)         1.778235e+10    3.0      15.648635   6.044636e-10
# C(condition)    2.041271e+11    4.0     134.725264   1.434478e-91
# C(grade)        7.618510e+11   11.0     182.846151  1.027685e-227
# bedrooms        4.706348e+11    1.0    1242.488860  6.210838e-176
# bathrooms       6.155457e+10    1.0     162.505755   1.583377e-34
# sqft_living     1.014352e+14    1.0  267791.853653   0.000000e+00
# sqft_lot        1.929970e+09    1.0       5.095173   2.421403e-02
# floors          3.847932e+07    1.0       0.101586   7.500026e-01
# year_built      4.748860e+06    1.0       0.012537   9.108709e-01
# year_renovated  1.106572e+08    1.0       0.292138   5.889776e-01
# lat             1.171190e+08    1.0       0.309198   5.783011e-01
# long            1.535702e+06    1.0       0.004054   9.492434e-01
# Residual        3.677992e+11  971.0            NaN            NaN

# %%
house_prices["year_renovated"].value_counts()
# Out:
# year_renovated
# 0       783
# 1993      8
# 1970      8
# 1998      6
# 1962      6
#        ...
# 1956      1
# 1953      1
# 2013      1
# 1967      1
# 1987      1
# Name: count, Length: 70, dtype: int64

# %%
# first convert the date to datetime format
house_prices['year_renovated']=pd.to_datetime(house_prices['year_renovated'])
house_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bedrooms        1000 non-null   int64
#  1   bathrooms       1000 non-null   int64
#  2   sqft_living     1000 non-null   int64
#  3   sqft_lot        1000 non-null   int64
#  4   floors          1000 non-null   int64
#  5   waterfront      1000 non-null   int64
#  6   view            1000 non-null   int64
#  7   condition       1000 non-null   int64
#  8   grade           1000 non-null   int64
#  9   year_built      1000 non-null   int64
#  10  year_renovated  1000 non-null   datetime64[ns]
#  11  lat             1000 non-null   float64
#  12  long            1000 non-null   float64
#  13  price           1000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(10)
# memory usage: 109.5 KB

# %%
#First convert the date to datetime
#house_prices_data["year_renovated"]= pd.to_datetime(house_prices_data["year_renovated"])
#house_prices_data.info()

# %%
#feature engineering years since renovation
current_year=pd.Timestamp.now().year
house_prices['years since renovation']=current_year-house_prices['year_renovated']
house_prices['years since renovation']=house_prices['years since renovation'].where(house_prices['year_renovated']>0,0)
house_prices.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          1         2803      1153       1           0     0
# 1         5          3          783      9762       1           0     2
# 2         3          3         3412      2842       2           0     3
# 3         2          3         2222      9020       2           1     2
# 4         4          1         4713      1584       2           0     3
#
#    condition  grade  year_built  year_renovated        lat        long  \
# 0          3      9        2003               0  47.660671 -121.785347
# 1          4      4        2019               0  47.681937 -122.151515
# 2          4      9        1961            1962  47.182798 -121.792089
# 3          4      4        2008            1962  47.440995 -121.871224
# 4          4      5        1987               0  47.701306 -122.416623
#
#         price  years since renovation
# 0   835016.23                       0
# 1   326073.09                       0
# 2  1025404.09                      63
# 3   758764.79                      63
# 4  1314784.23                       0

# %%
house_prices["year_renovated"].value_counts()
# Out:
# year_renovated
# 0       783
# 1993      8
# 1970      8
# 1998      6
# 1962      6
#        ...
# 1956      1
# 1953      1
# 2013      1
# 1967      1
# 1987      1
# Name: count, Length: 70, dtype: int64

# %%
correlations1 = house_prices.corr()
#Correlation Heatmap
plt.figure(figsize=(12,12))
sns.heatmap(data=correlations1, cmap= "coolwarm", annot=True)
# Out:
# <Axes: >

# %%
# vif
x=house_prices.drop(["price",],axis=1)
x = add_constant(x)

# compute VIF
vif_data=pd.DataFrame()
vif_data["Feature"]=x.columns
vif_data["VIF"]=[variance_inflation_factor(x.values,i)
                 for i in range(x.shape[1])]
print(vif_data)
# Out:
#                    Feature            VIF
# 0                    const  245129.128832
# 1                 bedrooms       1.013823
# 2                bathrooms       1.011420
# 3              sqft_living       1.009564
# 4                 sqft_lot       1.031680
# 5                   floors       1.008520
# 6               waterfront       1.011411
# 7                     view       1.024152
# 8                condition       1.012444
# 9                    grade       1.013428
# 10              year_built       1.004342
# 11          year_renovated       3.926888
# 12                     lat       1.006288
# 13                    long       1.022625
# 14  years since renovation       3.913710

# %%
x = x.drop('year_renovated', axis =1)

# Compute VIF to check for multicollinearity
vif_data = pd.DataFrame()
vif_data["Feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i)
                   for i in range(x.shape[1])]

print(vif_data)
# Out:
#                    Feature            VIF
# 0                    const  245112.406652
# 1                 bedrooms       1.006154
# 2                bathrooms       1.011025
# 3              sqft_living       1.008733
# 4                 sqft_lot       1.031534
# 5                   floors       1.008497
# 6               waterfront       1.008859
# 7                     view       1.023083
# 8                condition       1.006595
# 9                    grade       1.008901
# 10              year_built       1.004057
# 11                     lat       1.006286
# 12                    long       1.022462
# 13  years since renovation       1.006717

# %%
numeric_cols=['price','sqft_living','bedrooms','bathrooms']

#Melt data into long format
house_prices_melted = house_prices[numeric_cols].melt(var_name='Variable', value_name='Value')

# Plot all boxplots in one chart
plt.figure(figsize=(10, 6))
sns.boxplot(x='Variable', y='Value', data=house_prices_melted, palette='coolwarm')
plt.title('Boxplots of Numeric Variables')
plt.xlabel('')
plt.ylabel('Value')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17312\1434269715.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Variable', y='Value', data=house_prices_melted, palette='coolwarm')

# %%
min_max_scaler=MinMaxScaler()
data_scaled=min_max_scaler.fit_transform(house_prices)
scaled_df=pd.DataFrame(data_scaled)
scaled_melted=scaled_df.melt(var_name='Variable', value_name=' Scaled Value')

plt.figure(figsize=(10, 6))
sns.boxplot(x='Variable', y=' Scaled Value', data=scaled_melted, palette='viridis')
plt.title('Boxplots of Scaled Normalized Scale (0-1)')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17312\1841689105.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Variable', y=' Scaled Value', data=scaled_melted, palette='viridis')

# %%
scaled_df.head()
# Out:
#      0    1         2         3    4    5         6     7         8   \
# 0  0.50  0.0  0.501137  0.016906  0.0  0.0  0.000000  0.50  0.727273
# 1  1.00  1.0  0.041629  0.974419  0.0  0.0  0.666667  0.75  0.272727
# 2  0.50  1.0  0.639672  0.204760  1.0  0.0  1.000000  0.75  0.727273
# 3  0.25  1.0  0.368972  0.891892  1.0  1.0  0.666667  0.75  0.272727
# 4  0.75  0.0  0.935623  0.064843  1.0  0.0  1.000000  0.75  0.363636
#
#          9         10        11        12        13    14
# 0  0.746479  0.000000  0.802321  0.714269  0.494323  0.00
# 1  0.971831  0.000000  0.832767  0.346790  0.093351  0.00
# 2  0.154930  0.970807  0.118177  0.707503  0.644321  0.84
# 3  0.816901  0.970807  0.487823  0.628085  0.434248  0.84
# 4  0.521127  0.000000  0.860496  0.080732  0.872309  0.00

# %%
price_normalized = np.log(y)
y_transformed = pd.Series(price_normalized)
print(y_transformed)
# Out:
# 0      13.635206
# 1      12.694877
# 2      13.840597
# 3      13.539447
# 4      14.089183
#          ...
# 995    13.453856
# 996    13.994396
# 997    13.443744
# 998    12.987000
# 999    12.420902
# Name: price, Length: 1000, dtype: float64

# %%
model=sm.OLS(price_normalized,scaled_df).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.971
# Model:                            OLS   Adj. R-squared (uncentered):              0.971
# Method:                 Least Squares   F-statistic:                              2213.
# Date:                Thu, 30 Oct 2025   Prob (F-statistic):                        0.00
# Time:                        10:36:04   Log-Likelihood:                         -2252.1
# No. Observations:                1000   AIC:                                      4534.
# Df Residuals:                     985   BIC:                                      4608.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              4.5360      0.279     16.263      0.000       3.989       5.083
# 1              1.9487      0.185     10.558      0.000       1.586       2.311
# 2             50.0943      3.834     13.065      0.000      42.570      57.618
# 3              2.1120      0.248      8.521      0.000       1.626       2.598
# 4              0.7398      0.145      5.091      0.000       0.455       1.025
# 5              4.5040      0.418     10.775      0.000       3.684       5.324
# 6              2.0758      0.192     10.836      0.000       1.700       2.452
# 7              3.4164      0.232     14.729      0.000       2.961       3.872
# 8              5.8885      0.350     16.842      0.000       5.202       6.575
# 9              2.4288      0.239     10.182      0.000       1.961       2.897
# 10             1.2443      0.356      3.492      0.001       0.545       1.944
# 11             2.4426      0.247      9.879      0.000       1.957       2.928
# 12             2.1141      0.244      8.681      0.000       1.636       2.592
# 13           -53.3833      4.448    -12.002      0.000     -62.112     -44.655
# 14            -0.9692      0.593     -1.635      0.102      -2.133       0.194
# ==============================================================================
# Omnibus:                        3.920   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                3.665
# Skew:                          -0.098   Prob(JB):                        0.160
# Kurtosis:                       2.778   Cond. No.                         144.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(scaled_df, price_normalized, test_size=0.2, random_state=42)

# ==============================================
# Define models
# ==============================================
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Lasso Regression": Lasso(alpha=0.001),
    "Decision Tree": DecisionTreeRegressor(max_depth=6, random_state=42),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "AdaBoost": AdaBoostRegressor(n_estimators=100, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=200, learning_rate=0.1, random_state=42, verbosity=0),
    "LightGBM": LGBMRegressor(n_estimators=200, learning_rate=0.1, random_state=42, verbose=-1),
    "CatBoost": CatBoostRegressor(iterations=200, learning_rate=0.1, depth=6, silent=True, random_state=42)
}

# ==============================================
# Train & evaluate each model
# ==============================================
results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    results.append({
        "Model": name,
        "RMSE": rmse,
        "R²": r2
    })

# ==============================================
# Results comparison
# ==============================================
results_df = pd.DataFrame(results).sort_values(by="RMSE")
print(results_df)
# Out:
#                Model      RMSE        R²
# 6            XGBoost  0.006073  0.999823
# 4      Random Forest  0.009899  0.999530
# 3      Decision Tree  0.013191  0.999165
# 7           LightGBM  0.022981  0.997467
# 8           CatBoost  0.023132  0.997433
# 5           AdaBoost  0.031396  0.995272
# 0  Linear Regression  0.097958  0.953971
# 2   Lasso Regression  0.098552  0.953412
# 1   Ridge Regression  0.099181  0.952815
