# %%
import numpy as np

# %%
#generate two lists with random integers between 1 and 3
list1 = [np.random.randint(1, 4) for i in range(16)]
list2 = [np.random.randint(1, 4) for i in range(16)]
list3 = [np.random.randint(1, 4) for i in range(16)]
print(list1)
print(list2)
print(list3)
# Out:
# [2, 3, 3, 3, 2, 1, 1, 2, 3, 2, 2, 2, 3, 3, 1, 3]
# [2, 1, 2, 2, 1, 3, 1, 1, 2, 1, 1, 1, 3, 2, 2, 3]
# [2, 3, 1, 3, 1, 3, 3, 2, 2, 2, 1, 3, 1, 3, 1, 2]
